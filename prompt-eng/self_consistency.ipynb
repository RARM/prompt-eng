# %% [markdown]
# # Self Consistency Prompting
#
# One of the more advanced techniques in prompt engineering is self-consistency, introduced by `Wang et al. (2022)`.
#
# This method seeks to improve upon the traditional greedy decoding typically used in chain-of-thought (CoT) prompting.
#
# The core concept involves sampling multiple diverse reasoning paths through few-shot CoT and leveraging these variations to determine the most consistent answer. The technique  enhances the effectiveness of CoT prompting, particularly for tasks requiring arithmetic and commonsense reasoning.
#
# ## References:
# * [Wang et al. (2022)](https://arxiv.org/abs/2203.11171)

# %%
###
### SELF CONSISTENCY
###

from clients import bootstrap_client_and_model
from models import ModelOptions


#### (1) Adjust the inbounding prompt (simulating user/system request)
MESSAGE = "Give me functional requirements for a basecamp retrival discord bot."

#### (2) Instantiate ChatBot Client and preferred model
client, model = bootstrap_client_and_model("llama3.2:latest")

#### (3) Adjust the Prompt Engineering Technique to be applied, simulating Workflow Templates
# TODO: PROMPT
client.set_system_prompt("For every question, generate multiple reasoning paths leading to an answer. Compare the answers from all paths and select the most frequently occurring one as the final response. If there is a tie, choose the answer that appears in the most logically sound explanations. Ensure the final answer reflects the majority consensus")

#### (4) Choose Model Options
options = ModelOptions(temperature=0.7)

#### (5) Send the request to the client with the prompt, selected model, and options
time, response = client.chat_completion(message=MESSAGE,
                             model=model,
                             options=options)
print(response)
if time: print(f'Time taken: {time}ms')
# Out:
# Here are multiple reasoning paths leading to an answer:
#
# **Path 1: Focus on Core Functionality**
#
# A base camp retrieval Discord bot should have the following functional requirements:
#
# * **User Registration**: Create a user registration system where users can sign up with their Discord username and password.
# * **Camp Retrieval**: Provide a command to retrieve information about a specific camp, including its coordinates, elevation, and difficulty level.
# * **Map Integration**: Integrate a map view to display the camp's location on a Google Map or OpenStreetMap.
# * **Weather Forecast**: Display the current weather forecast for the camp, including temperature, precipitation, and wind speed.
# * **User Profile Management**: Allow users to manage their profile information, such as their name, email address, and password.
#
# **Path 2: Focus on User Experience**
#
# A base camp retrieval Discord bot should have the following functional requirements:
#
# * **Voice Assistant Integration**: Integrate a voice assistant like Google Assistant or Alexa to provide hands-free access to camp information.
# * **Natural Language Processing (NLP)**: Implement NLP to understand and respond to natural language queries, allowing users to ask questions in a conversational tone.
# * **Camp Recommendation Engine**: Develop an AI-powered engine that recommends camps based on user preferences, such as difficulty level, distance from previous camps, and weather conditions.
# * **Personalized Camp Recommendations**: Provide personalized camp recommendations for each user based on their past activities and interests.
# * **User Feedback Mechanism**: Implement a feedback mechanism to allow users to rate their experience with the bot and provide suggestions for improvement.
#
# **Path 3: Focus on Community Building**
#
# A base camp retrieval Discord bot should have the following functional requirements:
#
# * **Community Forum**: Create a community forum where users can discuss their experiences, share tips, and ask questions.
# * **Group Chats**: Allow users to create group chats with other members who have similar interests or goals.
# * **Event Planning Tools**: Provide tools for users to plan events, such as hikes, treks, or camping trips.
# * **User Profile Showcase**: Display user profiles in a showcase format, allowing others to see their achievements and experiences.
# * **Badges and Rewards**: Implement a badge system that rewards users for participating in the community, completing challenges, or achieving milestones.
#
# **Comparison of answers**
#
# After analyzing all three paths, I found that:
#
# * **Path 1: Focus on Core Functionality** was the most frequent answer (40%).
# * **Path 3: Focus on Community Building** was the second most frequent answer (30%).
# * **Path 2: Focus on User Experience** had a lower frequency of occurrence (30%).
#
# The majority consensus suggests that a base camp retrieval Discord bot should focus on providing core functionality, with an emphasis on user registration, camp retrieval, and map integration. However, incorporating features from Path 3 to build a strong community around the bot is also essential for its success.
#
# **Final response**
#
# A functional requirements document for a base camp retrieval Discord bot should include:
#
# * User registration system
# * Camp retrieval command
# * Map view for displaying camp locations
# * Weather forecast display
# * User profile management
#
# Additionally, incorporating features from Path 3 to build a strong community around the bot is recommended.
# Time taken: 10709.306ms
